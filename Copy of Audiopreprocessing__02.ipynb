# %%
# !pip install spleeter

# !pip install pydub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 89.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 36.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyannote-audio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.7/208.7 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 22.4 MB/s eta 0:00:00
# ...

# %%
# !pip install protobuf==3.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.2
#     Uninstalling protobuf-4.25.2:
#       Successfully uninstalled protobuf-4.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.4.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-api-core 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# ...

# %%
# !pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import spleeter
from __future__ import unicode_literals
from IPython.display import Audio
from pydub import AudioSegment
from pydub.silence import split_on_silence
import csv
from pathlib import Path
from termcolor import colored
import os
import pandas as pd

# %%
import torch
from pydub import AudioSegment

# %%
from pyannote.audio import Model
model = Model.from_pretrained("pyannote/segmentation",use_auth_token='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' )
from pyannote.audio.pipelines import OverlappedSpeechDetection
# Out:
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.1.3. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/2ffce0501d0aecad81b43a06d538186e292d0070/pytorch_model.bin`
# ...

# %%
HYPER_PARAMETERS = {
  # onset/offset activation thresholds
  "onset": 0.4, "offset": 0.4,
  # remove speech regions shorter than that many seconds.
  "min_duration_on": 0.7,
  # fill non-speech regions shorter than that many seconds.
  "min_duration_off": 0.0
}

# %%
import numpy as np
pipeline = OverlappedSpeechDetection(segmentation=model)
pipeline.instantiate(HYPER_PARAMETERS)

# %%
import os
os.makedirs("/content/download",exist_ok=True)
os.makedirs("/content/vocalsplitted",exist_ok=True)
os.makedirs("/content/audiochunks",exist_ok=True)
os.makedirs("/content/segments",exist_ok=True)

# %%
from pytube import YouTube
def download_audio(youtube_url, output_path='./'):
    try:
        # Create a YouTube object
        yt = YouTube(youtube_url)

        # Get the highest resolution stream (for videos) or audio stream (for audio-only)
        audio_stream = yt.streams.filter(only_audio=True).first()

        # Download the audio stream
        name=audio_stream.download(output_path)

        print("Audio download completed.",name)

    except Exception as e:
        print(f"Error: {str(e)}")

    return name

# Example usage:
# Replace 'https://www.youtube.com/watch?v=your_video_id' with the actual YouTube video URL

# %%
from datetime import datetime

def split_wav(input_file, output_prefix, segment_length=5 * 60 * 1000):
    # Load the input audio file
    audio = AudioSegment.from_file(input_file, format="wav")

    # Calculate the number of segments
    num_segments = len(audio) // segment_length + 1
    os.makedirs(output_prefix,exist_ok=True)
    for i in range(num_segments):
        # Calculate start and end time for each segment
        start_time = i * segment_length
        end_time = (i + 1) * segment_length
        timestamp = datetime.now().strftime("%Y%m%d%H%M%S%f")
        # Extract the segment
        segment = audio[start_time:end_time]

        # Create output file name
        output_file = f"{output_prefix}/segment_{i + 1}_t_{timestamp}.wav"

        # Export the segment to a new WAV file
        segment.export(output_file, format="wav")

# %%
def convert_audio(audio_file):
    """
    Corrects the channels, sample rate, and sample width of the audios.
    Replaces the original audio file with the one generated.
    """
    sound = AudioSegment.from_file(audio_file)
    sound = sound.set_frame_rate(16000)
    sound = sound.set_channels(1)
    sound = sound.set_sample_width(2)
    temfilename=audio_file[:-3]+"wav"
    sound.export(temfilename, format ="wav")
    os.remove(audio_file)
    return temfilename

# %% [markdown]
# ## downloading only part

# %%
download_df=pd.read_csv("/content/download_status.csv")
for idx,row in download_df.iterrows():
   filename=download_audio(row['filelink'], output_path='/content/download/')
   download_df.loc[idx, 'dnldstatus'] = 1
   download_df.loc[idx, 'filename']=filename
   filename=convert_audio(filename)
   split_wav(filename, '/content/segments')
   download_df.to_csv("/content/download_status.csv", index=False)
# Out:
# Audio download completed. /content/download/Ujjwal Bikram Thapa  Paradygm Podcasts  057.mp4
# Audio download completed. /content/download/Yash Kumar !! Biswa Limbu Podcast Ep 208 @yashkumar1116.mp4

# %% [markdown]
# ## splitting vocals and noise

# %%
import pandas as pd
from glob import glob
import gc
links=glob("/content/segments/*.wav")
segment_df=pd.read_csv("/content/vocalsplit_status.csv")
data = {'filelocation': links}
data_df = pd.DataFrame(data)
data_df['vocalsepstatus']=0
segment_df=pd.concat([segment_df,data_df],ignore_index=True)
segment_df.to_csv("/content/vocalsplit_status.csv",index=False)

# %%
from glob import glob
import gc
vocal_df=pd.read_csv('/content/vocalsplit_status.csv')
for idx,row in vocal_df.iterrows():
  if row["vocalsepstatus"] ==2 :
    print("already")
    continue
  elif row["vocalsepstatus"] == 1:
    # delete all the vocals for broken pieces
    continue
  #code to change the audio into processable segment
  link=row['filelocation']
  vocal_df.loc[idx,'vocalsepstatus'] = 1
  vocal_df.to_csv("/content/vocalsplit_status.csv",index=False)
  # !spleeter separate -p spleeter:2stems -o '/content/vocalsplitted' "{link}"
  vocal_df.loc[idx,'vocalsepstatus'] = 2

  vocal_df.to_csv("/content/vocalsplit_status.csv",index=False)
  gc.collect()
# Out:
# already
# already
# already
# already
# already
# already
# INFO:spleeter:File /content/vocalsplitted/segment_8_t_20240116173112254835/vocals.wav written succesfully
# INFO:spleeter:File /content/vocalsplitted/segment_8_t_20240116173112254835/accompaniment.wav written succesfully
# 2
# INFO:spleeter:File /content/vocalsplitted/segment_2_t_20240116173142137661/vocals.wav written succesfully
# INFO:spleeter:File /content/vocalsplitted/segment_2_t_20240116173142137661/accompaniment.wav written succesfully
# ^C
# 2
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# ...

# %%
import pandas as pd
vocal_df=pd.read_csv('/content/vocalsplit_status.csv')
vocal_df=pd.read_csv('/content/vocalsplit_status.csv')
vocal_df.head(20)
# match_df=vocal_df[vocal_df["vocalsepstatus"]==2.0]
# print(match_df)
# Out:
#                                          filelocation  vocalsepstatus
# 0   /content/segments/segment_1_t_2024011617311205...               2
# 1   /content/segments/segment_19_t_202401161731125...               2
# 2   /content/segments/segment_6_t_2024011617314224...               2
# 3   /content/segments/segment_3_t_2024011617311211...               2
# 4   /content/segments/segment_14_t_202401161731124...               2
# 5   /content/segments/segment_17_t_202401161731124...               2
# 6   /content/segments/segment_9_t_2024011617314234...               1
# 7   /content/segments/segment_8_t_2024011617311225...               2
# 8   /content/segments/segment_2_t_2024011617314213...               2
# 9   /content/segments/segment_7_t_2024011617314228...               2
# 10  /content/segments/segment_1_t_2024011617314211...               1
# 11  /content/segments/segment_4_t_2024011617314217...               0
# ...

# %% [markdown]
# ## splitting into chinks and finding overlap

# %%
from glob import glob
vocallinks=glob("/content/vocalsplitted/*/vocals.wav")
chunk_df=pd.read_csv("/content/filechunk_status.csv")
data = {'vocalfilelink': vocallinks}
chunksata_df = pd.DataFrame(data)
chunksata_df['chunkstatus']=0
chunk_df=pd.concat([chunksata_df,chunk_df],ignore_index=True)
chunk_df.to_csv("/content/filechunk_status.csv", index=False)

# %%
 #     continue # continue with the next link in the file
from glob import glob
import numpy as np
chunk_df=pd.read_csv("/content/filechunk_status.csv")



for idx,row in chunk_df.iterrows():
        if row["chunkstatus"] ==2 :
          print("already")
          continue
        elif row["chunkstatus"] == 1:
            # delete all the vocals for broken pieces
            continue
                # give link to all the vocals.wav file

        link_num=idx
        # Step 4: Split into smaller parts
        filename=row['vocalfilelink']
        sound_file = AudioSegment.from_wav(filename)
        audio_chunks = split_on_silence(sound_file,
            # must be silent for at least half a second
            min_silence_len=500,

            # consider it silent if quieter than -16 dBFS
            silence_thresh=-50
        )
        print ("exporting files for link number: ",link_num)

        os.makedirs(f"/content/audiochunks/{link_num}",exist_ok=True)
        #combining chunks if small and making it splited if big
        target_length = 10 * 1000
        output_chunks = [audio_chunks[0]]
        for chunk in audio_chunks[1:]:
            if len(output_chunks[-1]) < target_length:
                output_chunks[-1] += chunk
                print("combined")
            else:
                # if the last output chunk is longer than the target length,
                # we can start a new one

                output_chunks.append(chunk)
        chunk_df.loc[idx,'chunkstatus'] = 1
        chunk_df.to_csv("/content/filechunk_status.csv", index=False)
         # making folder named after link number we are processing
        for i, chunk in enumerate(output_chunks):
            out_file = "/content/audiochunks/{0}/{0}_{1}.wav".format(link_num, i)
            #code to check if it has overlapping sound
            samples = np.array(chunk.get_array_of_samples())
            samples=samples.reshape(1,-1)
            torsamples=torch.from_numpy(samples).float()
            data={"waveform": torsamples, "sample_rate": 16000}
            osd = pipeline(data)
            if len(osd)>1:
              print("not saved")
              print(out_file)
              print(osd)
              continue


            chunk.export(out_file, format="wav")
        chunk_df.loc[idx,'chunkstatus']=2
        chunk_df.to_csv("/content/filechunk_status.csv", index=False)
# Out:
# already
# already
# already
# already
# exporting files for link number:  4
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined
# combined

# %%
import shutil
shutil.rmtree("/content/sample_data/splitted")

# %% [markdown]
# ## making csv

# %%
# Create a DataFrame with the desired columns and data
data = {'filelink': ['https://www.youtube.com/watch?v=WatXucJcTgY',
                     'https://www.youtube.com/watch?v=PI_HD5_gz6E'
                    #  'https://www.youtube.com/watch?v=j-I2ipptuZA',
                    #  'https://www.youtube.com/watch?v=HiRrXN9u40Y',
                    #  'https://www.youtube.com/watch?v=XJshM7iB-5Y'
                     ],
        'dnldstatus': [0,0],
        'filename' :["n","n"]
        }

download_df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
download_df.to_csv('download_status.csv', index=False)

# %%
# Create a DataFrame with the desired columns and data
data = {'filelocation': []
                    ,
        'vocalsepstatus': []}

segment_df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
segment_df.to_csv('vocalsplit_status.csv', index=False)

# %%
# Create a DataFrame with the desired columns and data
data = {'vocalfilelink': [],
        'chunkstatus': []}

chunk_df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
chunk_df.to_csv('filechunk_status.csv', index=False)

# %%
vocal_df=pd.read_csv("/content/vocalsplit_status.csv")
for idx,row in vocal_df.iterrows():
  if row["vocalsepstatus"] ==2 :
    continue
  elif row["vocalsepstatus"] == 1:
    # delete all the vocals for broken pieces
    pass
  #code to change the audio into processable segment

# %%
import pandas as pd
chunk_df.head(20)
# Out:
# Empty DataFrame
# Columns: [vocalfilelink, chunkstatus]
# Index: []

# %%
download_df.head(10)
# Out:
#                                       filelink  dnldstatus  \
# 0  https://www.youtube.com/watch?v=WatXucJcTgY           1
# 1  https://www.youtube.com/watch?v=PI_HD5_gz6E           1
# 2  https://www.youtube.com/watch?v=j-I2ipptuZA           1
# 3  https://www.youtube.com/watch?v=HiRrXN9u40Y           0
# 4  https://www.youtube.com/watch?v=XJshM7iB-5Y           0
#
#                                             filename
# 0  /content/download/Ujjwal Bikram Thapa  Paradyg...
# 1  /content/download/Yash Kumar !! Biswa Limbu Po...
# 2  /content/download/Episode 211 Ramchandra Shres...
# 3                                                  n
# 4                                                  n

# %%
vocal_df=pd.read_csv('/content/vocalsplit_status.csv')
vocal_df.head(20)
# match_df=vocal_df[vocal_df["vocalsepstatus"]==2.0]
# print(match_df)
columns = vocal_df.columns
print(columns)
# Out:
# Index(['filelocation', 'vocalsepstatus'], dtype='object')

# %%
segment_df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0         0.0
# 1             1         1.0
# 2             2         2.0
# 3             3         3.0
# 4             4         4.0
# 5             5         5.0
# 6             6         6.0
# 7             7         7.0
# 8             8         8.0
# 9             9         9.0
#
#                                         filelocation  vocalsepstatus
# 0  /content/segments/segment_2_t_2024011511293844...               0
# 1  /content/segments/segment_6_t_2024011511301566...               0
# 2  /content/segments/segment_8_t_2024011511293856...               0
# 3  /content/segments/segment_7_t_2024011511304252...               0
# 4  /content/segments/segment_5_t_2024011511301564...               0
# 5  /content/segments/segment_1_t_2024011511293842...               0
# 6  /content/segments/segment_13_t_202401151129386...               0
# 7  /content/segments/segment_7_t_2024011511293853...               0
# ...

# %%
chunk_df.head(10)
# Out:
#                                        vocalfilelink  chunkstatus
# 0  /content/vocalsplitted/segment_19_t_2024011617...            2
# 1  /content/vocalsplitted/segment_8_t_20240116173...            1
# 2  /content/vocalsplitted/segment_2_t_20240116173...            0
# 3  /content/vocalsplitted/segment_9_t_20240116173...            0
# 4  /content/vocalsplitted/segment_1_t_20240116173...            0
# 5  /content/vocalsplitted/segment_1_t_20240116173...            0
